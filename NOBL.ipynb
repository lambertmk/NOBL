# %%
import numpy as np # analysis
import pandas as pd # for dataframe
import matplotlib.pyplot as plt # plotting
import seaborn as sns # fancy plotting
from scipy import stats # testing

# %%
data = pd.read_csv('NOBL Questions from adapt survey.csv')

# %%
data
# Out:
#                      Sector                      Industry Group  \
# 0               Industrials  Commercial & professional services
# 1                Government               Australian Government
# 2                    Energy                              Energy
# 3                Financials                         Real Estate
# 4                Financials                               Banks
# ..                      ...                                 ...
# 116             Industrials  Commercial & professional services
# 117              Financials              Diversified Financials
# 118             Health Care    Health Care Equipment & Services
# 119  Consumer discretionary                               Media
# 120  Information Technology                 Software & Services
#
#                             Industry  \
# 0     Commercial Services & Supplies
# 1                   Australian State
# 2        Oil, Gas & Consumable Fuels
# 3                        Real Estate
# ...

# %%
data['Which letter most closely represents where you are on this cloud journey?'] = data['Which letter most closely represents where you are on this cloud journey']

# %%
# create new column for letter only

data.letter = data['Which letter most closely represents where you are on this cloud journey?'].astype(str).str[0]
data.letter.value_counts()
# Out:
# J    37
# I    18
# L    18
# G    13
# F     8
# K     8
# M     7
# C     5
# H     3
# E     2
# A     1
# D     1
# Name: Which letter most closely represents where you are on this cloud journey?, dtype: int64

# %%
sns.set_theme(style="ticks")
sns.color_palette("crest_r", as_cmap=True)

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    data,
    x=data.letter)

# %%
sns.set_theme(style="whitegrid")

f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.scatterplot(x=data.letter, y=data.Employees,
                data=data, ax=ax)

# no clear relationship here

# %%
sns.set_theme(style="whitegrid")

f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.scatterplot(y=data.letter, x=data.Employees,
                data=data, ax=ax)

# same when the axes are switched

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    data,
    x=data.letter, hue=data.Sector,
    multiple="stack",
    palette="crest_r")
